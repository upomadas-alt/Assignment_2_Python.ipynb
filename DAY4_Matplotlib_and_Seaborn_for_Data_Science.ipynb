# %% [markdown]
# <a href="https://colab.research.google.com/github/upomadas-alt/Assignment_2_Python.ipynb/blob/main/DAY4_Matplotlib_and_Seaborn_for_Data_Science.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install required packages (run this first in Google Colab)
# !pip install numpy pandas matplotlib seaborn

# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **Dataset**

# %%
from google.colab import files
uploaded = files.upload()
# Upload: StudentsPerformance.csv and gym_membership.csv

# Load data
students = pd.read_csv('StudentsPerformance.csv')
gym = pd.read_csv('gym_membership.csv')
# Out:
#      <input type="file" id="files-1e461fd3-c780-477c-b851-7bf804bab298" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1e461fd3-c780-477c-b851-7bf804bab298">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ## **Understand the Data**

# %% [markdown]
# # **Gym Data Exploration**

# %%
import warnings
warnings.filterwarnings('ignore')
# The gym DataFrame has already been loaded in cell u7f_GrtTMqbb
# gym = pd.read_csv('/content/drive/MyDrive/datasets/gym_membership.csv')

# %%
# Gym data

# Display last 5 rows
print("Last 5 rows of the gym DataFrame:")
display(gym.tail())

# Check data types
print("\nData types of the gym DataFrame:")
display(gym.dtypes)
# Out:
# Last 5 rows of the gym DataFrame:
#        id  gender    birthday  Age abonoment_type  visit_per_week  \
# 995   996  Female  1984-09-22   40       Standard               3
# 996   997  Female  2008-11-19   15       Standard               3
# 997   998    Male  1984-10-05   40       Standard               2
# 998   999    Male  2001-02-22   23       Standard               4
# 999  1000  Female  2006-05-07   18        Premium               2
#
#           days_per_week  attend_group_lesson fav_group_lesson  \
# 995       Thu, Tue, Wed                False              NaN
# 996       Fri, Mon, Sun                 True     XCore, Zumba
# 997            Fri, Tue                False              NaN
# 998  Mon, Sun, Thu, Tue                 True       HIT, XCore
# 999            Thu, Tue                False              NaN
#
#     avg_time_check_in avg_time_check_out  avg_time_in_gym  drink_abo  \
# 995          20:56:00           22:42:00              106      False
# ...

# %%
# Task 1: Basic Matplotlib (3 plots)
# 1. Bar chart of gym membership types
plt.figure(figsize=(8, 6))
gym['abonoment_type'].value_counts().plot(kind='bar')
plt.title('Distribution of Gym Membership Types')
plt.xlabel('Membership Type')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()

# 2. Histogram of time in gym
plt.figure(figsize=(8, 6))
plt.hist(gym['avg_time_in_gym'], bins=20)
plt.title('Distribution of Average Time in Gym')
plt.xlabel('Average Time in Gym (minutes)')
plt.ylabel('Frequency')
plt.show()

# 3. Scatter plot: Age vs visits per week
plt.figure(figsize=(8, 6))
plt.scatter(gym['Age'], gym['visit_per_week'])
plt.title('Age vs Visits per Week')
plt.xlabel('Age')
plt.ylabel('Visits per Week')
plt.show()

# %%
# 1. Box plot: Gender vs Age
plt.figure(figsize=(8, 6))
sns.boxplot(data=gym, x='gender', y='Age')
plt.title('Gender vs Age')
plt.show()

# 2. Count plot: Days per week
plt.figure(figsize=(10, 6))
sns.countplot(data=gym, x='days_per_week')
plt.title('Count of Visits per Day of the Week')
plt.xlabel('Day of the Week')
plt.ylabel('Count')
plt.show()

# 3. Bar plot: Average visits by membership type
plt.figure(figsize=(8, 6))
sns.barplot(data=gym, x='abonoment_type', y='visit_per_week')
plt.title('Average Visits per Week by Membership Type')
plt.xlabel('Membership Type')
plt.ylabel('Average Visits per Week')
plt.show()
